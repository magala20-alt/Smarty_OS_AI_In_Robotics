# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\sebab\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.3.4

# %%
# Load pretrained YOLOv8 model
model = YOLO("yolov8m.pt")

# %%
# Train (transfer learning)
model.train(
    data="datasets/data.yaml",  # dataset config
    epochs=10,
    batch=8,
    imgsz=640,
    lr0=0.01,
    optimizer="SGD",
    momemtum=0.9,
    freeze=20,         # freeze backbone layers
    device="cpu",          # GPU (or 'cpu')
    project="runs/train",  # where results are saved
    name="toy_animals_model",
    verbose=True
)

# %%
model.train(
    data="datasets/data.yaml",
    epochs=40,                 # fine-tuning phase
    batch=4,
    imgsz=640,
    lr0=0.001,                 # smaller LR when unfreezing
    optimizer="SGD",
    momentum=0.9,
    weight_decay=5e-4,
    freeze=0,                  # unfreeze all
    device="cpu",
    project="runs/train",
    name="toy_animals_full",
    verbose=True
)
