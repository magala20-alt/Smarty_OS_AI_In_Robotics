# %%
import socket
import threading
import json
import time

# run the server directly inside notebook
# !python mock_pi_server.py

HOST = '127.0.0.1'
PORT = 9001

def handle_conn(conn, addr):
    print('Connected by', addr)
    with conn:
        data = conn.recv(2048)
        if not data:
            return
        msg = data.decode().lower()
        print('Received:', msg)
        time.sleep(1)

        # --- inside handle_conn ---
        animals = ['lion', 'tiger', 'elephant', 'zebra', 'giraffe', 'leopard']
        found_animal = next((animal for animal in animals if animal in msg), None)

        if 'grab' in msg and found_animal:
            resp = {'status': 'grab', 'message': f'Dora grabbed the {found_animal}! 🤗'}
        elif 'put' in msg and 'back' in msg:
            resp = {'status': 'putback', 'message': 'Yay! We did it! 🎉'}
        elif found_animal:
            resp = {'status': 'happy', 'message': f'Dora found the {found_animal}! 🐾'}
        else:
            resp = {'status': 'sad', 'message': 'Hmm... Dora could not find it 😢'}

        conn.send(json.dumps(resp).encode())

def server():
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.bind((HOST, PORT))
    s.listen()
    print('Mock Pi server listening on', HOST, PORT)
    while True:
        conn, addr = s.accept()
        threading.Thread(target=handle_conn, args=(conn, addr)).start()

if __name__ == '__main__':
    server()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\mehtaab\OneDrive\Desktop\jupyter\mock_pi_server.py", line 44, in <module>
#     server()
#   File "C:\Users\mehtaab\OneDrive\Desktop\jupyter\mock_pi_server.py", line 36, in server
#     s.bind((HOST, PORT))
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted
# Mock Pi server listening on 127.0.0.1 9001
# Connected by ('127.0.0.1', 9938)
# Received: get / http/1.1
# host: 127.0.0.1:9001
# connection: keep-alive
# sec-ch-ua: "chromium";v="122", "not(a:brand";v="24", "google chrome";v="122"
# sec-ch-ua-mobile: ?0
# sec-ch-ua-platform: "windows"
# upgrade-insecure-requests: 1
# user-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/122.0.6261.95 safari/537.36
# accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
# sec-fetch-site: cross-site
# sec-fetch-mode: navigate
# sec-fetch-user: ?1
# sec-fetch-dest: document
# referer: http://localhost:8888/notebooks/onedrive/desktop/jupyter/app.ipynb
# accept-encoding: gzip, deflate, br
# accept-language: en-us,en;q=0.9
#
#
# Connected by ('127.0.0.1', 9939)
# Connected by ('127.0.0.1', 9948)
# Received: get / http/1.1
# host: 127.0.0.1:9001
# connection: keep-alive
# sec-ch-ua: "chromium";v="122", "not(a:brand";v="24", "google chrome";v="122"
# sec-ch-ua-mobile: ?0
# sec-ch-ua-platform: "windows"
# upgrade-insecure-requests: 1
# user-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/122.0.6261.95 safari/537.36
# accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
# sec-fetch-site: cross-site
# sec-fetch-mode: navigate
# sec-fetch-user: ?1
# sec-fetch-dest: document
# accept-encoding: gzip, deflate, br
# accept-language: en-us,en;q=0.9
#
#
# Connected by ('127.0.0.1', 9949)
# Connected by ('127.0.0.1', 1694)
# Received: get / http/1.1
# host: 127.0.0.1:9001
# connection: keep-alive
# sec-ch-ua: "google chrome";v="141", "not?a_brand";v="8", "chromium";v="141"
# sec-ch-ua-mobile: ?0
# sec-ch-ua-platform: "windows"
# upgrade-insecure-requests: 1
# user-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/141.0.0.0 safari/537.36
# accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
# sec-fetch-site: none
# sec-fetch-mode: navigate
# sec-fetch-user: ?1
# sec-fetch-dest: document
# accept-encoding: gzip, deflate, br, zstd
# accept-language: en-gb,en-us;q=0.9,en;q=0.8,fr;q=0.7
#
#
# Connected by ('127.0.0.1', 47196)
# Received: get / http/1.1
# host: 127.0.0.1:9001
# connection: keep-alive
# cache-control: max-age=0
# sec-ch-ua: "google chrome";v="141", "not?a_brand";v="8", "chromium";v="141"
# sec-ch-ua-mobile: ?0
# sec-ch-ua-platform: "windows"
# upgrade-insecure-requests: 1
# user-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/141.0.0.0 safari/537.36
# accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
# sec-fetch-site: none
# sec-fetch-mode: navigate
# sec-fetch-user: ?1
# sec-fetch-dest: document
# accept-encoding: gzip, deflate, br, zstd
# accept-language: en-gb,en-us;q=0.9,en;q=0.8,fr;q=0.7
#
#
# Connected by ('127.0.0.1', 26814)
